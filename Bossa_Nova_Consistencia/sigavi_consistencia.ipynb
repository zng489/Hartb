# %% [markdown]
# # Sigavi
# # Consistência

# %%
# Read the parquet file
import boto3
import io
import pandas as pd
import dask.dataframe as dd

import requests
import concurrent.futures
from concurrent.futures import as_completed
import os
import aiohttp
from typing import List
import random
import asyncio
import time
from time import sleep
import re

# %%
#db = ['db-sigavi-full/Cargo',
#'db-sigavi-full/Cliente',
#'db-sigavi-full/ClienteComplemento',


db = ['db-sigavi-full/ClienteContato',
'db-sigavi-full/ClienteStatus',
'db-sigavi-full/ClienteTelefone',
'db-sigavi-full/Colaborador',
'db-sigavi-full/ColaboradorTelefone',
'db-sigavi-full/Divisao',
'db-sigavi-full/Empreendimento',
'db-sigavi-full/EmpreendimentoCaracteristica',
'db-sigavi-full/EmpreendimentoClassificacao',
'db-sigavi-full/EmpreendimentoComercializacao',
'db-sigavi-full/EmpreendimentoEstado',
'db-sigavi-full/EmpreendimentoFase',
'db-sigavi-full/EmpreendimentoPortal',
'db-sigavi-full/EmpreendimentoTipo',
'db-sigavi-full/EmpreendimentoTipologia',
'db-sigavi-full/Endereco',
'db-sigavi-full/Equipe',
'db-sigavi-full/EstadoCivil',
'db-sigavi-full/Fac',
'db-sigavi-full/FacApresentacao',
'db-sigavi-full/FacApresentacaoImovel',
'db-sigavi-full/FacAvaliacao',
'db-sigavi-full/FacCanal',
'db-sigavi-full/FacClassificacao',
'db-sigavi-full/FacEstiloMorar',
'db-sigavi-full/FacFaixaRenda',
'db-sigavi-full/FacGestao',
'db-sigavi-full/FacInteresse',
'db-sigavi-full/FacInteresseComplemento',
'db-sigavi-full/FacMidia',
'db-sigavi-full/FacMomento',
'db-sigavi-full/FacMotivoFinalizar',
'db-sigavi-full/FacPersonalizado2',
'db-sigavi-full/FacSituacaoAtendimento',
'db-sigavi-full/FacSituacaoContato',
'db-sigavi-full/FacStatusGestao',
'db-sigavi-full/FacTemperatura',
'db-sigavi-full/FacTipoAcao',
'db-sigavi-full/FacTipoAtividade',
'db-sigavi-full/FaixaEtaria',
'db-sigavi-full/FollowUp',
'db-sigavi-full/HistoricoEmail',
'db-sigavi-full/Imovel',
'db-sigavi-full/ImovelCaptador',
'db-sigavi-full/ImovelCaracteristica',
'db-sigavi-full/ImovelCategoriaCaracteristica',
'db-sigavi-full/ImovelClassificacao',
'db-sigavi-full/ImovelFinalidade',
'db-sigavi-full/ImovelFormaCaptacao',
'db-sigavi-full/ImovelFoto',
'db-sigavi-full/ImovelPlaca',
'db-sigavi-full/ImovelPlacaStatus',
'db-sigavi-full/ImovelPortal',
'db-sigavi-full/ImovelStatus',
'db-sigavi-full/ImovelTipo',
'db-sigavi-full/ImovelTipoCaracteristica',
'db-sigavi-full/ImovelTipoPlaca',
'db-sigavi-full/ImovelTipoUnidade',
'db-sigavi-full/ImovelValorSite',
'db-sigavi-full/LogAcao',
'db-sigavi-full/LogDadosContato',
'db-sigavi-full/LogFuncao',
'db-sigavi-full/LogInformacao',
'db-sigavi-full/LogSistema',
'db-sigavi-full/LogSistemaInformacao',
'db-sigavi-full/Midia',
'db-sigavi-full/MidiaCampanhaMidiaCategoria',
'db-sigavi-full/Moeda',
'db-sigavi-full/Nacionalidade',
'db-sigavi-full/OnlineContato',
'db-sigavi-full/OnlinePreLead',
'db-sigavi-full/OnlinePreLeadInformacao',
'db-sigavi-full/Portal',
'db-sigavi-full/PortalDestaque',
'db-sigavi-full/Profissao',
'db-sigavi-full/Proposta',
'db-sigavi-full/PropostaComissao',
'db-sigavi-full/SecretariaMotivoCancelamento',
'db-sigavi-full/Sexo',
'db-sigavi-full/SistemaSegmento',
'db-sigavi-full/TipoCreci',
'db-sigavi-full/TipoEndereco',
'db-sigavi-full/TipoLogradouro',
'db-sigavi-full/Unidade',
'db-sigavi-full/UnidadeStatus']

# %%
storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}

for path in db:
    pd.set_option('display.max_columns', None)
    d = dd.read_parquet(f's3://bossa-nova-sss/{path}/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks
    print(path)
    display(d.head())

# %%
d.head()
# CpfCnpj
#Email
# Out:
#        Id  IdCliente  IdConjuge  Sexo Nascimento OrgaoExpeditor DataExpedicao  \
# 0  176818     306859        NaN   1.0       None           None          None
# 1  192069     322131        NaN   2.0       None           None          None
# 2   33355      32644        NaN   1.0       None           None          None
# 3   59811     188397        NaN   1.0       None           None          None
# 4   14268      13503        NaN   NaN       None           None          None
#
#    IdNacionalidade Naturalidade UFNacimento  IdProfissao  IdEstadoCivil  \
# 0              1.0         None        None          NaN            NaN
# 1              1.0         None        None          NaN            NaN
# 2              1.0         None        None          NaN            NaN
# 3              NaN         None        None          NaN            NaN
# 4              NaN         None        None          NaN            NaN
#
# ...

# %%
# Read the parquet file
import boto3
import io
import pandas as pd
import dask.dataframe as dd

import requests
import concurrent.futures
from concurrent.futures import as_completed
import os
import aiohttp
from typing import List
import random
import asyncio
import time
from time import sleep
import re


def email_validate(row):
    regex = re.compile(r'([A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+')
    emails = row.reply_to_address
    try: 
        for i, val in enumerate(emails):
            if(re.search(regex,emails)):   
                return 'Email Valido'
            else:   
                return 'Email Invalido'
    except TypeError:
        return 'Email Invalido'
    

def celular_validate(row):
    regex = re.compile(r'([0-9]{2})([0-9]{4,5})([0-9]{4})+')
    celular = row.CELULAR
    try: 
        for i, val in enumerate(celular):
            if(re.search(regex,celular)):   
                return 'Celular Valido'
            else:   
                return 'Celular Invalido'
    except TypeError:
        return 'Celular Invalido'
    
'''
def zipcode_validate(row):
    regex = re.compile(r'([0-9]{8})+')
    cep = row.zipcode
    try: 
        for i, val in enumerate(cep):
            if(re.search(regex,cep)):   
                return 'Zipcode Valido'
            else:   
                return 'Zipcode Invalido'
    except TypeError:
        return 'Zipcode Invalido'
'''

    
def cep_validate(row):
    regex = re.compile(r'([0-9]{8})+')
    cep = row.cep
    try: 
        for i, val in enumerate(cep):
            if(re.search(regex,cep)):   
                return 'CEP Valido'
            else:   
                return 'CEP Invalido'
    except TypeError:
        return 'CEP Invalido'
    

def documento_validate(row):
    numbers = row.documentoContribuinte1 #CPF
    try: 
        for i, val in enumerate(numbers):
            #  Obtém os números do CPF e ignora outros caracteres
            cpf = [int(char) for char in numbers if char.isdigit()]

            #  Verifica se o CPF tem 11 dígitos
            if len(cpf) != 11:
                return 'Documento Invalido'
            
            #  Verifica se o CPF tem todos os números iguais, ex: 111.111.111-11
            #  Esses CPFs são considerados inválidos mas passam na validação dos dígitos
            if cpf == cpf[::-1]:
                return 'Documento Invalido'

            #  Valida os dois dígitos verificadores
            for i in range(9, 11):
                value = sum((cpf[num] * ((i+1) - num) for num in range(0, i)))
                digit = ((value * 10) % 11) % 10
                if digit != cpf[i]:  
                    return 'Documento Invalido'
            return 'Documento Valido'
    except TypeError:
        return 'Documento Invalido'
    


 
#db = 

# 'db-mautic/mktpage_hits' RODANDO SEPARADO
# 'db-mautic/mktemail_stats' RODANDO SEPARADO



storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}

for path in db:
    d = dd.read_parquet(f's3://bossa-nova-sss/{path}/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks
    #print(d.columns)


    for e in d.columns:
        #print(e)
        if e == 'reply_to_address':
            print('                                                           ')
            print('                                                           ')
            print(f'>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA {path}')
            print('                                                           ')
            print('                                                           ')
            d['email_validation'] = d.apply(email_validate,axis=1)
            display(d.compute())
            #display(d[(d["email_validation"] == 'Email Invalido')].compute())
            print('Registros de email Invalido:',len(d[(d["email_validation"] == 'Email Invalido')]))
            d.to_csv(r"C:\Users\PC\Desktop\Bossa_Nova_Project\Completude_Consistencia\consistencia\{e}*.csv".format(e=e))

        else:
            pass

# %%
storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}
pd.set_option('display.max_columns', None)
d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/OnlinePreLead/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks
print(path)
display(d.head())

def email_validate(row):
    regex = re.compile(r'([A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+')
    emails = row.Email
    try: 
        for i, val in enumerate(emails):
            if(re.search(regex,emails)):   
                return 'Email Valido'
            else:   
                return 'Email Invalido'
    except TypeError:
        return 'Email Invalido'
    

def celular_validate(row):
    regex = re.compile(r'([0-9]{2})([0-9]{4,5})([0-9]{4})+')
    celular = row.Telefone
    try: 
        for i, val in enumerate(celular):
            if(re.search(regex,celular)):   
                return 'Telefone Valido'
            else:   
                return 'Telefone Invalido'
    except TypeError:
        return 'Telefone Invalido'
    
if __name__ == '__main__':
    storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}
    pd.set_option('display.max_columns', None)
    d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/OnlinePreLead/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks  
    #print(path)
    #display(d.head())

    d['email_validation'] = d.apply(email_validate,axis=1)
    display(d.compute())
    #display(d[(d["email_validation"] == 'Email Invalido')].compute())
    print('Registros de email Invalido:',len(d[(d["email_validation"] == 'Email Invalido')]))

    d['telefone_validation'] = d.apply(celular_validate,axis=1)
    display(d.compute())
    #display(d[(d["email_validation"] == 'Email Invalido')].compute())
    print('Registros de telefone Invalido:',len(d[(d["telefone_validation"] == 'Telefone Invalido')]))
# Out:
# db-sigavi-full/ClienteTelefone
#        Id  IdSegmento Praca UF Cidade Bairro Referencia ReferenciaPortal  \
# 0   98719         2.0                             67004
# 1   67710         2.0                             33141
# 2   21520         2.0                             45309
# 3  125457         1.0                             13587
# 4  120934         2.0                             29969
#
#            Campanha            Nome                    Email     Telefone  \
# 0                     Maria Eduarda  Maria.dobbin@c6bank.com  11988618989
# 1  midiaonlinebnsir  Daniel Schmidt     danielfs79@gmail.com  11983831308
# 2          facebook       Carolina   cervone.cario@gmail.com  11993777574
# 3                ig    Monica Kenan   Monica.kenan@gmail.com  11981722366
# 4         ig-social      Luana poli    luana.apoli@gmail.com  11994409007
#
#   Celular                                           Mensagem  Empreendimento  \
# ...

# %%
storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}
pd.set_option('display.max_columns', None)
d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/ClienteContato/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks
print(path)
display(d.head())

def email_validate(row):
    regex = re.compile(r'([A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+')
    emails = row.Email
    try: 
        for i, val in enumerate(emails):
            if(re.search(regex,emails)):   
                return 'Email Valido'
            else:   
                return 'Email Invalido'
    except TypeError:
        return 'Email Invalido'
    
    
if __name__ == '__main__':
    storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}
    pd.set_option('display.max_columns', None)
    d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/OnlinePreLead/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks  
    #print(path)
    #display(d.head())

    d['email_validation'] = d.apply(email_validate,axis=1)
    display(d.compute())
    #display(d[(d["email_validation"] == 'Email Invalido')].compute())
    print('Registros de email Invalido:',len(d[(d["email_validation"] == 'Email Invalido')]))
# Out:
# db-sigavi-full/ClienteTelefone
#        Id  IdCliente  Nome Cargo                           Email Telefone  \
# 0  418311     219899  None  None       BALTA_PINHEIRO@UOL.COM.BR     None
# 1  498423     309030  None  None  andreza.favero@ificina1.com.br     None
# 2  501509     218245  None  None          marsiajgomes@gmail.com     None
# 3  417804     219328  None  None           ierdnaodarp@gmail.com     None
# 4  467811     276161  None  None            flavialawyer@aol.com     None
#
#    ContatoExterno   DDI
# 0           False  None
# 1           False  None
# 2           False  None
# 3           False  None
# 4           False  None
# c:\Users\PC\miniconda3\envs\miniconda_0\lib\site-packages\dask\dataframe\core.py:5690: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# ...

# %%
def celular_validate(row):
    regex = re.compile(r'([0-9]{2})([0-9]{4,5})([0-9]{4})+')
    celular = row.Join_DDD_Numero
    try: 
        for i, val in enumerate(celular):
            if(re.search(regex,celular)):   
                return 'Telefone Valido'
            else:   
                return 'Telefone Invalido'
    except TypeError:
        return 'Telefone Invalido'
    
    
if __name__ == '__main__':
    storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}
    pd.set_option('display.max_columns', None)
    d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/ColaboradorTelefone/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks
    print(path)
    display(d.head())
    #print(path)
    #display(d.head())
    display(d.columns)
    d['Join_DDD_Numero'] = d['DDD'].astype(str) + d['Numero'].astype(str)
    display(d.head())


    d['telefone_validation'] = d.apply(celular_validate,axis=1)
    display(d.compute())
    #display(d[(d["email_validation"] == 'Email Invalido')].compute())
    print('Registros de telefone Invalido:',len(d[(d["telefone_validation"] == 'Telefone Invalido')]))
# Out:
# db-sigavi-full/ClienteTelefone
#      Id  IdColaborador  Ativo  IdTipoTelefone DDD     Numero Ramal   DDI
# 0  1344           5002   True               2  98    1611890  None  None
# 1   342           2862   True               2  11  982327556  None  None
# 2   422           2970   True               2  11  985260651  None  None
# 3    37           1029   True               2  11  991112221  None  None
# 4   598           3112   True               1  11   36811713  None  None
# Index(['Id', 'IdColaborador', 'Ativo', 'IdTipoTelefone', 'DDD', 'Numero',
#        'Ramal', 'DDI'],
#       dtype='object')
#      Id  IdColaborador  Ativo  IdTipoTelefone DDD     Numero Ramal   DDI  \
# 0  1344           5002   True               2  98    1611890  None  None
# 1   342           2862   True               2  11  982327556  None  None
# 2   422           2970   True               2  11  985260651  None  None
# 3    37           1029   True               2  11  991112221  None  None
# ...

# %%
def email_validate_De(row):
    regex = re.compile(r'([A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+')
    emails = row.De
    try: 
        for i, val in enumerate(emails):
            if(re.search(regex,emails)):   
                return 'Email Valido'
            else:   
                return 'Email Invalido'
    except TypeError:
        return 'Email Invalido'
    

def email_validate_Para(row):
    regex = re.compile(r'([A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+')
    emails = row.Para
    try: 
        for i, val in enumerate(emails):
            if(re.search(regex,emails)):   
                return 'Email Valido'
            else:   
                return 'Email Invalido'
    except TypeError:
        return 'Email Invalido'


def email_validate_Cco(row):
    regex = re.compile(r'([A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+')
    emails = row.Cco
    try: 
        for i, val in enumerate(emails):
            if(re.search(regex,emails)):   
                return 'Email Valido'
            else:   
                return 'Email Invalido'
    except TypeError:
        return 'Email Invalido'
    
    
if __name__ == '__main__':
    storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}
    pd.set_option('display.max_columns', None)
    d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/HistoricoEmail/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks
    print(path)
    display(d.head())
    #print(path)
    #display(d.head())
    display(d.columns)


    d['email_validation_De'] = d.apply(email_validate_De,axis=1)
    display(d.compute())
    #display(d[(d["email_validation"] == 'Email Invalido')].compute())
    print('Registros de email_De Invalido:',len(d[(d["email_validation_De"] == 'Email Invalido')]))

    d['email_validation_Para'] = d.apply(email_validate_Para,axis=1)
    display(d.compute())
    #display(d[(d["email_validation"] == 'Email Invalido')].compute())
    print('Registros de email_Para Invalido:',len(d[(d["email_validation_Para"] == 'Email Invalido')]))

    d['email_validation_Cco'] = d.apply(email_validate_Cco,axis=1)
    display(d.compute())
    #display(d[(d["email_validation"] == 'Email Invalido')].compute())
    print('Registros de email_Cco Invalido:',len(d[(d["email_validation_Cco"] == 'Email Invalido')]))
# Out:
# db-sigavi-full/ClienteTelefone
#        Id  IdStatus  IdRegistro Funcao                Descricao  IdSmtp  \
# 0   51439         3      228893    FAC  Apresentação de Imóveis       1
# 1  106547         3           0                                       1
# 2   22099         3      190354    FAC  Apresentação de Imóveis       1
# 3   24282         3      149429    FAC           Envio pela Fac       1
# 4   82272         3      207418    FAC  Apresentação de Imóveis       1
#
#                             De                     Para Cc  \
# 0  imoveis@bossanovasir.com.br    maitaaredes@gmail.com
# 1  imoveis@bossanovasir.com.br  jamileamorimf@gmail.com
# 2  imoveis@bossanovasir.com.br       brunoato@gmail.com
# 3  imoveis@bossanovasir.com.br    diaspedro95@gmail.com
# 4  imoveis@bossanovasir.com.br      schiesar@uol.com.br
#
#                              Cco  \
# 0   jribeiro@bossanovasir.com.br
# 1
# 2       claudio@bnsvendas.com.br
# 3  rcecchele@bossanovasir.com.br
# ...

# %%
storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}
pd.set_option('display.max_columns', None)
d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/LogDadosContato/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks
print(path)
display(d.head())
# Out:
# db-sigavi-full/ClienteTelefone
#          Id  IdEmpresa  IdUsuario                Data             IP     Tipo  \
# 0  17434203       3075       2513 2021-11-09 22:42:35  179.209.46.34  Cliente
# 1  17809552       3075       2514 2022-05-08 11:10:46    177.9.7.141  Cliente
# 2  15225861          4       3422 2021-06-16 15:22:33       cron job  Cliente
# 3  15996647          4       3719 2021-06-22 11:32:13       cron job  Cliente
# 4   8526167          4       2770 2021-05-14 18:49:28     191.13.3.4  Cliente
#
#                        Nome                           Email         Telefone  \
# 0                Crys kulba            crys.kulba@gmail.com  (11) 94518-7677
# 1                      None                            None             None
# 2  Fernanda/Marcelo Semione             fsemeoni@msn.com.br  (11) 99943-0922
# 3              Vera Bariani           vc.bariani@uol.com.br  (11) 98584-1103
# 4             Márcio Borges  marcio.a.borges@merckgroup.com  (11) 99603-9539
#
# ...

# %%
def email_validate(row):
    regex = re.compile(r'([A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+')
    emails = row.Email
    try: 
        for i, val in enumerate(emails):
            if(re.search(regex,emails)):   
                return 'Email Valido'
            else:   
                return 'Email Invalido'
    except TypeError:
        return 'Email Invalido'
    

def celular_validate(row):
    regex = re.compile(r'([0-9]{2})([0-9]{4,5})([0-9]{4})+')
    celular = row.Telefone
    try: 
        for i, val in enumerate(celular):
            if(re.search(regex,celular)):   
                return 'Telefone Valido'
            else:   
                return 'Telefone Invalido'
    except TypeError:
        return 'Telefone Invalido'
    

    
def cep_validate(row):
    regex = re.compile(r'([0-9]{8})+')
    cep = row.Cep
    try: 
        for i, val in enumerate(cep):
            if(re.search(regex,cep)):   
                return 'CEP Valido'
            else:   
                return 'CEP Invalido'
    except TypeError:
        return 'CEP Invalido'
    

def documento_validate(row):
    numbers = row.CpfCnpj #CPF
    try: 
        for i, val in enumerate(numbers):
            #  Obtém os números do CPF e ignora outros caracteres
            cpf = [int(char) for char in numbers if char.isdigit()]

            #  Verifica se o CPF tem 11 dígitos
            if len(cpf) != 11:
                return 'Documento Invalido'
            
            #  Verifica se o CPF tem todos os números iguais, ex: 111.111.111-11
            #  Esses CPFs são considerados inválidos mas passam na validação dos dígitos
            if cpf == cpf[::-1]:
                return 'Documento Invalido'

            #  Valida os dois dígitos verificadores
            for i in range(9, 11):
                value = sum((cpf[num] * ((i+1) - num) for num in range(0, i)))
                digit = ((value * 10) % 11) % 10
                if digit != cpf[i]:  
                    return 'Documento Invalido'
            return 'Documento Valido'
    except TypeError:
        return 'Documento Invalido'

# %%
def email_validate(row):
    regex = re.compile(r'([A-Za-z0-9]+[.-_])*[A-Za-z0-9]+@[A-Za-z0-9-]+(\.[A-Z|a-z]{2,})+')
    emails = row.Email
    try: 
        for i, val in enumerate(emails):
            if(re.search(regex,emails)):   
                return 'Email Valido'
            else:   
                return 'Email Invalido'
    except TypeError:
        return 'Email Invalido'
    

def celular_validate(row):
    regex = re.compile(r'([0-9]{2})([0-9]{4,5})([0-9]{4})+')
    celular = row.Telefone
    try: 
        for i, val in enumerate(celular):
            if(re.search(regex,celular)):   
                return 'Telefone Valido'
            else:   
                return 'Telefone Invalido'
    except TypeError:
        return 'Telefone Invalido'
    

    
def cep_validate(row):
    regex = re.compile(r'([0-9]{8})+')
    cep = row.Cep
    try: 
        for i, val in enumerate(cep):
            if(re.search(regex,cep)):   
                return 'CEP Valido'
            else:   
                return 'CEP Invalido'
    except TypeError:
        return 'CEP Invalido'
    

def documento_validate(row):
    numbers = row.CpfCnpj #CPF
    try: 
        for i, val in enumerate(numbers):
            #  Obtém os números do CPF e ignora outros caracteres
            cpf = [int(char) for char in numbers if char.isdigit()]

            #  Verifica se o CPF tem 11 dígitos
            if len(cpf) != 11:
                return 'Documento Invalido'
            
            #  Verifica se o CPF tem todos os números iguais, ex: 111.111.111-11
            #  Esses CPFs são considerados inválidos mas passam na validação dos dígitos
            if cpf == cpf[::-1]:
                return 'Documento Invalido'

            #  Valida os dois dígitos verificadores
            for i in range(9, 11):
                value = sum((cpf[num] * ((i+1) - num) for num in range(0, i)))
                digit = ((value * 10) % 11) % 10
                if digit != cpf[i]:  
                    return 'Documento Invalido'
            return 'Documento Valido'
    except TypeError:
        return 'Documento Invalido'
    

db = ['db-sigavi-full/OnlinePreLead',
'db-sigavi-full/OnlineContato',
'db-sigavi-full/LogDadosContato']
# https://stackoverflow.com/questions/4843158/how-to-check-if-a-string-is-a-substring-of-items-in-a-list-of-strings

storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}

for path in db:
    d = dd.read_parquet(f's3://bossa-nova-sss/{path}/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks
    display(d.columns)
    for e in d.columns:
        #print(e)
        if e == 'Email':
            print('                                                           ')
            print('                                                           ')
            print(f'>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA {path}')
            print('                                                           ')
            print('                                                           ')
            d['email_validation'] = d.apply(email_validate,axis=1)
            display(d.compute())
            #display(d[(d["email_validation"] == 'Email Invalido')].compute())
            print('Registros de email Invalido:',len(d[(d["email_validation"] == 'Email Invalido')]))
        
        elif e == 'Cep':
            print('                                                           ')
            print('                                                           ')
            print(f'>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA {path}')
            print('                                                           ')
            print('                                                           ')
            #d['prod_type'] = d['zipcode'].str.replace('-','responsvie', regex=True)
            d['cep'] = d['cep'].str.replace('-','')

            d['cep_validation'] = d.apply(cep_validate,axis=1)
            display(d.compute())
            #display(d[(d["cep_validation"] == 'Cep Invalido')].compute())
            print('Registros de CEP Invalido:',len(d[(d["cep_validation"] == 'CEP Invalido')]))

        elif e == 'Telefone':
            print('                                                           ')
            print('                                                           ')
            print(f'>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA {path}')
            print('                                                           ')
            print('                                                           ')
            #d['prod_type'] = d['zipcode'].str.replace('-','responsvie', regex=True)

            d['Telefone_validation'] = d.apply(celular_validate,axis=1)
            display(d.compute())
            #display(d[(d["cep_validation"] == 'Cep Invalido')].compute())
            print('Registros de Telefone Invalido:',len(d[(d["Telefone_validation"] == 'Telefone Invalido')]))

        else:
            pass
# Out:
# Index(['Id', 'IdSegmento', 'Praca', 'UF', 'Cidade', 'Bairro', 'Referencia',
#        'ReferenciaPortal', 'Campanha', 'Nome', 'Email', 'Telefone', 'Celular',
#        'Mensagem', 'Empreendimento', 'DataCadastro', 'IdStatus',
#        'IdOnlineContato', 'DataProcessado', 'Erro', 'CpfCnpj', 'IdCorretor',
#        'Canal', 'ExpectativaFechamento', 'DDI', 'CodigoExterno'],
#       dtype='object')
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA db-sigavi-full/OnlinePreLead
# c:\Users\PC\miniconda3\envs\miniconda_0\lib\site-packages\dask\dataframe\core.py:5690: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'object'))
#
# ...

# %%
def documento_validate(row):
    numbers = row.CpfCnpj #CPF
    try: 
        for i, val in enumerate(numbers):
            #  Obtém os números do CPF e ignora outros caracteres
            cpf = [int(char) for char in numbers if char.isdigit()]

            #  Verifica se o CPF tem 11 dígitos
            if len(cpf) != 11:
                return 'Documento Invalido'
            
            #  Verifica se o CPF tem todos os números iguais, ex: 111.111.111-11
            #  Esses CPFs são considerados inválidos mas passam na validação dos dígitos
            if cpf == cpf[::-1]:
                return 'Documento Invalido'

            #  Valida os dois dígitos verificadores
            for i in range(9, 11):
                value = sum((cpf[num] * ((i+1) - num) for num in range(0, i)))
                digit = ((value * 10) % 11) % 10
                if digit != cpf[i]:  
                    return 'Documento Invalido'
            return 'Documento Valido'
    except TypeError:
        return 'Documento Invalido'

# %%
def documento_validate(row):
    numbers = row.CpfCnpj #CPF
    try: 
        for i, val in enumerate(numbers):
            #  Obtém os números do CPF e ignora outros caracteres
            cpf = [int(char) for char in numbers if char.isdigit()]

            #  Verifica se o CPF tem 11 dígitos
            if len(cpf) != 11:
                return 'Documento Invalido'
            
            #  Verifica se o CPF tem todos os números iguais, ex: 111.111.111-11
            #  Esses CPFs são considerados inválidos mas passam na validação dos dígitos
            if cpf == cpf[::-1]:
                return 'Documento Invalido'

            #  Valida os dois dígitos verificadores
            for i in range(9, 11):
                value = sum((cpf[num] * ((i+1) - num) for num in range(0, i)))
                digit = ((value * 10) % 11) % 10
                if digit != cpf[i]:  
                    return 'Documento Invalido'
            return 'Documento Valido'
    except TypeError:
        return 'Documento Invalido'
    

db = 'db-sigavi-full/OnlinePreLead',
#'db-sigavi-full/OnlineContato',
#'db-sigavi-full/LogDadosContato']
# https://stackoverflow.com/questions/4843158/how-to-check-if-a-string-is-a-substring-of-items-in-a-list-of-strings

storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}


d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/OnlinePreLead/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks


print('                                                           ')
print('                                                           ')
print(f'>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA {path}')
print('                                                           ')
print('                                                           ')
#d['prod_type'] = d['zipcode'].str.replace('-','responsvie', regex=True)

d['CpfCnpj_validation'] = d.apply(documento_validate,axis=1)
display(d.compute())


display(d.compute())
#display(d[(d["cep_validation"] == 'Cep Invalido')].compute())
print('Registros de CpfCnpj Invalido:',len(d[(d["CpfCnpj_validation"] == 'Documento Invalido')]))
# Out:
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA db-sigavi-full/LogDadosContato
# c:\Users\PC\miniconda3\envs\miniconda_0\lib\site-packages\dask\dataframe\core.py:5690: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'object'))
#
#   warnings.warn(meta_warning(meta))
#           Id  IdSegmento Praca UF Cidade Bairro Referencia ReferenciaPortal  \
# 0      98719         2.0                             67004
# 1      67710         2.0                             33141
# 2      21520         2.0                             45309
# 3     125457         1.0                             13587
# ...

# %%
storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}


d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/OnlineContato/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks

print('                                                           ')
print('                                                           ')
print(f'>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA {path}')
print('                                                           ')
print('                                                           ')


d['CpfCnpj'] = (d['CpfCnpj'].str.replace('-','')).str.replace('.','')

d['CpfCnpj_validation'] = d.apply(documento_validate,axis=1)
display(d.compute())

#display(d[(d["cep_validation"] == 'Cep Invalido')].compute())
print('Registros de CpfCnpj Invalido:',len(d[(d["CpfCnpj_validation"] == 'Documento Invalido')]))
# Out:
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA db-sigavi-full/LogDadosContato
# c:\Users\PC\miniconda3\envs\miniconda_0\lib\site-packages\dask\dataframe\accessor.py:89: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   out = getattr(getattr(obj, accessor, obj), attr)(*args, **kwargs)
# c:\Users\PC\miniconda3\envs\miniconda_0\lib\site-packages\dask\dataframe\core.py:5690: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'object'))
#
#   warnings.warn(meta_warning(meta))
# ...

# %%
storage_options = {'anon':False,'key': 'AKIATWV4QX5GHCJJKQV5', 'secret':'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'}


d = dd.read_parquet(f's3://bossa-nova-sss/db-sigavi-full/LogDadosContato/*.parquet',blocksize=25e6 , storage_options=storage_options)  # 25MB chunks

print('                                                           ')
print('                                                           ')
print(f'>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA {path}')
print('                                                           ')
print('                                                           ')


#d['CpfCnpj'] = (d['CpfCnpj'].str.replace('-','')).str.replace('.','')

d['CpfCnpj_validation'] = d.apply(documento_validate,axis=1)
display(d.compute())

#display(d[(d["cep_validation"] == 'Cep Invalido')].compute())
print('Registros de CpfCnpj Invalido:',len(d[(d["CpfCnpj_validation"] == 'Documento Invalido')]))
# Out:
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> TABELA db-sigavi-full/LogDadosContato
# c:\Users\PC\miniconda3\envs\miniconda_0\lib\site-packages\dask\dataframe\core.py:5690: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'object'))
#
#   warnings.warn(meta_warning(meta))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\PC\Desktop\Bossa_Nova_Project\Completude_Consistencia\consistencia\sigavi_consistencia.ipynb Cell 17 in 1
# ...
