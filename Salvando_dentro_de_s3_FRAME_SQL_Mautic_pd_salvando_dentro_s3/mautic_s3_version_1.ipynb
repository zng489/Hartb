# %%
# !pip install pymysql
# !pip install s3contents
# !pip install s3fs
####################
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 1.3 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 808.4 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 4.8 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.1/136.1 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 9.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
#!pip install fastparquet
#!pip install dask
import dask.dataframe as dd
import boto3

# %%
#Creating Session With Boto3.
session = boto3.Session(
aws_access_key_id='####################',
aws_secret_access_key='####################'
)

# %%
mautic_table = "mktasset_downloads"
save_table_name = mautic_table+".parquet"
URI = "s3://bossa-nova-sss/db-mautic/pdi-test/"+save_table_name
print(URI)
#save_table_name = "mktasset_downloads.csv"
# Out:
# s3://bossa-nova-sss/db-mautic/pdi-test/mktasset_downloads.parquet

# %%
cnx = create_engine('mysql+pymysql://datalake:yb797wdZnigKP!To@private-db3-prd-rds.cyor9py5rdhu.sa-east-1.rds.amazonaws.com/mkt')    
conn = cnx.connect()
result = conn.execute(f'SELECT * FROM mkt.{mautic_table};').fetchall()
df = pd.DataFrame(result)
#print(df)

# %%
#Spezza archivio in parti
#ddf = dd.from_pandas(df, chunksize=5000000)

# %%
#Crete and storage in S3 csv file
#df.to_csv(URI, storage_options={'key': 'AKIATWV4QX5GGOPTQVZT', 'secret': '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'})

# %%
#Crete and storage in S3 parquet file
df.to_parquet(URI, engine='auto', compression='snappy', index=None, partition_cols='id', 
              storage_options={'key': '####################',
              'secret': '####################'})

# %%
#  https://www.stackvidhya.com/write-pandas-dataframe-as-csv-to-s3-using-boto3/
# https://www.carolynlangen.com/blog/2017-11-22-interacting-with-aws-s3-using-python-in-a-jupyter-notebook/

# %%
#############
#Esempio
#############
#import dask.dataframe as dd

#ddf = dd.from_pandas(df, chunksize=5000000)
#save_dir = '/path/to/save/'
#ddf.to_parquet(save_dir)
